# %%
import pandas as pd
pd.read_csv('posts.csv', encoding="windows-1251")
# Out:
#                                                  url  \
# 0        https://www.linkedin.com/in/vera-katasonova
# 1  https://www.linkedin.com/in/nikita-dmitriev-11...
# 2  https://www.linkedin.com/in/nikita-dmitriev-11...
# 3  https://www.linkedin.com/in/nikita-dmitriev-11...
# 4  https://www.linkedin.com/in/nikita-dmitriev-11...
# 5  https://www.linkedin.com/in/nikita-dmitriev-11...
# 6               https://www.linkedin.com/in/aiyumrin
# 7               https://www.linkedin.com/in/aiyumrin
# 8               https://www.linkedin.com/in/aiyumrin
# 9               https://www.linkedin.com/in/aiyumrin
#
#                                                 text  likes_cnt reposts_cnt  \
# 0  Jigar Sahu is #hiring. Know anyone who might b...          1           0
# 1  Hi everyone - I am looking for a new role and ...          2           0
# 2  Всем доброго времени суток! Я - крутой специал...         39   2 reposts
# ...
